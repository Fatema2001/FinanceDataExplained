# %%
# !pip install azure-storage-blob
# !pip install boto3
# !pip install google-cloud-storage
# Out:
# Collecting azure-storage-blob
#   Downloading azure_storage_blob-12.19.1-py3-none-any.whl (394 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.5/394.5 kB 5.1 MB/s eta 0:00:0000:0100:01
# Collecting isodate>=0.6.1
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 1.4 MB/s eta 0:00:00
# Collecting azure-core<2.0.0,>=1.28.0
#   Downloading azure_core-1.30.1-py3-none-any.whl (193 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.4/193.4 kB 7.2 MB/s eta 0:00:00
# Requirement already satisfied: cryptography>=2.1.4 in /Users/fatemaahmed/opt/anaconda3/lib/python3.9/site-packages (from azure-storage-blob) (37.0.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/fatemaahmed/opt/anaconda3/lib/python3.9/site-packages (from azure-storage-blob) (4.3.0)
# Requirement already satisfied: requests>=2.21.0 in /Users/fatemaahmed/opt/anaconda3/lib/python3.9/site-packages (from azure-core<2.0.0,>=1.28.0->azure-storage-blob) (2.28.1)
# Collecting typing-extensions>=4.3.0
#   Downloading typing_extensions-4.11.0-py3-none-any.whl (34 kB)
# Requirement already satisfied: six>=1.11.0 in /Users/fatemaahmed/opt/anaconda3/lib/python3.9/site-packages (from azure-core<2.0.0,>=1.28.0->azure-storage-blob) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in /Users/fatemaahmed/opt/anaconda3/lib/python3.9/site-packages (from cryptography>=2.1.4->azure-storage-blob) (1.15.1)
# Requirement already satisfied: pycparser in /Users/fatemaahmed/opt/anaconda3/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob) (2.21)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/fatemaahmed/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/fatemaahmed/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/fatemaahmed/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in /Users/fatemaahmed/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (3.3)
# Installing collected packages: typing-extensions, isodate, azure-core, azure-storage-blob
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.3.0
#     Uninstalling typing_extensions-4.3.0:
#       Successfully uninstalled typing_extensions-4.3.0
# Successfully installed azure-core-1.30.1 azure-storage-blob-12.19.1 isodate-0.6.1 typing-extensions-4.11.0
# Requirement already satisfied: boto3 in /Users/fatemaahmed/opt/anaconda3/lib/python3.9/site-packages (1.24.28)
# Requirement already satisfied: botocore<1.28.0,>=1.27.28 in /Users/fatemaahmed/opt/anaconda3/lib/python3.9/site-packages (from boto3) (1.27.28)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/fatemaahmed/opt/anaconda3/lib/python3.9/site-packages (from boto3) (0.10.0)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /Users/fatemaahmed/opt/anaconda3/lib/python3.9/site-packages (from boto3) (0.6.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/fatemaahmed/opt/anaconda3/lib/python3.9/site-packages (from botocore<1.28.0,>=1.27.28->boto3) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /Users/fatemaahmed/opt/anaconda3/lib/python3.9/site-packages (from botocore<1.28.0,>=1.27.28->boto3) (1.26.11)
# Requirement already satisfied: six>=1.5 in /Users/fatemaahmed/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.28.0,>=1.27.28->boto3) (1.16.0)
# Collecting google-cloud-storage
#   Downloading google_cloud_storage-2.16.0-py2.py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.6/125.6 kB 2.4 MB/s eta 0:00:0000:01
# Collecting google-crc32c<2.0dev,>=1.0
#   Downloading google_crc32c-1.5.0-cp39-cp39-macosx_10_9_x86_64.whl (30 kB)
# Collecting google-cloud-core<3.0dev,>=2.3.0
#   Downloading google_cloud_core-2.4.1-py2.py3-none-any.whl (29 kB)
# Collecting google-auth<3.0dev,>=2.26.1
#   Downloading google_auth-2.29.0-py2.py3-none-any.whl (189 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.2/189.2 kB 11.3 MB/s eta 0:00:00
# Collecting google-api-core<3.0.0dev,>=2.15.0
#   Downloading google_api_core-2.18.0-py3-none-any.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.3/138.3 kB 5.5 MB/s eta 0:00:00
# Collecting google-resumable-media>=2.6.0
#   Downloading google_resumable_media-2.7.0-py2.py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /Users/fatemaahmed/opt/anaconda3/lib/python3.9/site-packages (from google-cloud-storage) (2.28.1)
# Collecting protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5
#   Downloading protobuf-4.25.3-cp37-abi3-macosx_10_9_universal2.whl (394 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.2/394.2 kB 10.6 MB/s eta 0:00:0000:01
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2
#   Downloading googleapis_common_protos-1.63.0-py2.py3-none-any.whl (229 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.1/229.1 kB 5.7 MB/s eta 0:00:0000:01
# Collecting proto-plus<2.0.0dev,>=1.22.3
#   Downloading proto_plus-1.23.0-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.8/48.8 kB 1.7 MB/s eta 0:00:00
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.3.3-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/fatemaahmed/opt/anaconda3/lib/python3.9/site-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage) (0.2.8)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/fatemaahmed/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/fatemaahmed/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/fatemaahmed/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /Users/fatemaahmed/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (3.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/fatemaahmed/opt/anaconda3/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=2.26.1->google-cloud-storage) (0.4.8)
# Installing collected packages: rsa, protobuf, google-crc32c, cachetools, proto-plus, googleapis-common-protos, google-resumable-media, google-auth, google-api-core, google-cloud-core, google-cloud-storage
# Successfully installed cachetools-5.3.3 google-api-core-2.18.0 google-auth-2.29.0 google-cloud-core-2.4.1 google-cloud-storage-2.16.0 google-crc32c-1.5.0 google-resumable-media-2.7.0 googleapis-common-protos-1.63.0 proto-plus-1.23.0 protobuf-4.25.3 rsa-4.9

# %%
import pandas as pd
import numpy as np
import json
import requests
from io import StringIO
import boto3
from azure.storage.blob import BlobServiceClient, ContainerClient
from google.cloud import storage

# %%
# Function
def azure_upload_blob(connect_str,container_name,blob_name, data):
    blob_service_client= BlobServiceClient.from_connection_string(connect_str)
    blob_client =blob_service_client.get_blob

# %%
Finance_raw = pd.read_csv('Purchase_Order_Quantity_Price_detail_for_Commodity_Goods_procurements_20240410.csv')

# %%
def azure_upload_blob(connect_str, container_name, blob_name, data):
    blob_service_client = BlobServiceClient.from_connection_string(connect_str)
    blob_client = blob_service_client.get_blob_client(container=container_name, blob=blob_name)
    blob_client.upload_blob(data, overwrite=True)
    print(f"Uploaded to Azure Blob: {blob_name}")

def azure_download_blob(connect_str, container_name, blob_name):
    blob_service_client = BlobServiceClient.from_connection_string(connect_str)
    blob_client = blob_service_client.get_blob_client(container=container_name, blob=blob_name)
    download_stream = blob_client.download_blob()
    return download_stream.readall()

def google_upload_blob(bucket_name, source_file_name, destination_blob_name):
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(destination_blob_name)
    blob.upload_from_filename(source_file_name)
    print(f"File {source_file_name} uploaded to {destination_blob_name}.")

def google_download_blob(bucket_name, source_blob_name, destination_file_name):
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(source_blob_name)
    blob.download_to_filename(destination_file_name)
    print(f"Blob {source_blob_name} downloaded to {destination_file_name}.")

def aws_upload_file(file_name, bucket, object_name=None):
    if object_name is None:
        object_name = os.path.basename(file_name)
    s3_client = boto3.client('s3')
    response = s3_client.upload_file(file_name, bucket, object_name)
    print(f"Uploaded {file_name} to S3 bucket {bucket}.")

def aws_download_file(bucket, object_name, file_name):
    s3_client = boto3.client('s3')
    s3_client.download_file(bucket, object_name, file_name)
    print(f"Downloaded {object_name} from S3 bucket {bucket}.")

# %%
print(Finance_raw.info())
print(Finance_raw.shape)
Finance_raw.head
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 291993 entries, 0 to 291992
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   COMMODITY              291993 non-null  object
#  1   COMMODITY_DESCRIPTION  291993 non-null  object
#  2   EXTENDED_DESCRIPTION   230005 non-null  object
#  3   QUANTITY               291993 non-null  float64
#  4   UNIT_OF_MEASURE        201673 non-null  object
#  5   UNIT_OF_MEAS_DESC      201673 non-null  object
#  6   UNIT_PRICE             291993 non-null  float64
#  7   ITM_TOT_AM             291993 non-null  float64
#  8   MASTER_AGREEMENT       214254 non-null  object
#  9   CONTRACT_NAME          291993 non-null  object
#  10  PURCHASE_ORDER         291993 non-null  object
#  11  AWARD_DATE             291993 non-null  object
#  12  VENDOR_CODE            291993 non-null  object
#  13  LGL_NM                 291993 non-null  object
#  14  AD_LN_1                291094 non-null  object
#  15  AD_LN_2                40724 non-null   object
#  16  CITY                   291094 non-null  object
#  17  ST                     290684 non-null  object
#  18  ZIP                    291094 non-null  object
#  19  CTRY                   291094 non-null  object
#  20  DATA_BUILD_DATE        291993 non-null  object
# dtypes: float64(3), object(18)
# memory usage: 46.8+ MB
# None
# (291993, 21)
# <bound method NDFrame.head of           COMMODITY                              COMMODITY_DESCRIPTION  \
# 0             20085                           Uniforms, Blended Fabric
# 1             20021  CLOTHING: ATHLETIC, CASUAL, DRESS, UNIFORM, WE...
# 2       34564115002         PROTECTOR EAR MUFF TYPE NR RATING 29/28/28
# 3             34072  Rescue Equipment, Supplies and Accessories Inc...
# 4       75035105006                             AGGREGATE TRAP ROCK 5T
# ...             ...                                                ...
# 291988        88538                                Chlorine, Liquefied
# 291989      2041362  CABLE, COMPUTER PATCH, PLENUM OR NON-PLENUM, 2...
# 291990      6305650                      PAINT, INTERIOR, ENAMEL, FLAT
# 291991  67034100006                CLAMP CI SERVICE 4 X 2 IN DBL STRAP
# 291992      7450841                                 EMULSIONS, ASPHALT
#
#                                      EXTENDED_DESCRIPTION  QUANTITY  \
# 0       R3830 - Uniform Rental & Laundry Service-Yard ...     0.000
# 1                     Champion Style C81878ST  Size Small    12.000
# 2       RC LN_____ QTY DEL_____ P/F_____ B/O_____ DEL ...    10.000
# 3                     PR354 Spec Ops Stock  NRS Throw Bag     5.000
# 4                                                     NaN   327.500
# ...                                                   ...       ...
# 291988                                Qty:22,000lbs@.2290     0.000
# 291989                                     AUXILIARY, 6FT     5.000
# 291990                                                NaN     3.000
# 291991  RC LN_____ QTY DEL_____ P/F_____ B/O_____ DEL ...     4.000
# 291992                                                NaN    63.158
#
#        UNIT_OF_MEASURE UNIT_OF_MEAS_DESC  UNIT_PRICE  ITM_TOT_AM  \
# 0                  NaN               NaN    0.000000      327.45
# 1                   PR              Pair    6.690000       80.28
# 2                   EA              Each   15.360000      153.60
# 3                   EA              Each   62.000000      310.00
# 4                 CUYD        Cubic Yard   54.540672    17862.07
# ...                ...               ...         ...         ...
# 291988             NaN               NaN    0.000000     5038.00
# 291989              EA              Each    3.000000       15.00
# 291990             CAN               Can  122.990000      368.97
# 291991              EA              Each   37.360000      149.44
# 291992              EA              Each    2.050000      129.47
#
#          MASTER_AGREEMENT                                      CONTRACT_NAME  \
# 0       MA7400NA130000062  R3830 - Uniform Laundry Serv. / Yard Trims - N...
# 1       MA8300GA080000183                                     AFD gym shorts
# 2       MA7400GC090000005                            MATERIAL NEEDED AT WBSC
# 3       MA8300GA160000040                               PR354 Spec Ops Stock
# 4       MA6200GA080000196                         Vulcan Materials/trap rock
# ...                   ...                                                ...
# 291988  MA2200GA110000036                       Liquid Chlorine in cylinders
# 291989                NaN                                             cables
# 291990                NaN  Sep. 2012 - Purchase of Paint for 411 Chicon -...
# 291991  MA2200GA120000044                            material needed at wbsc
# 291992  MA6200NA090000173                                 Ergon Asphalt/SS-1
#
#         ...  AWARD_DATE   VENDOR_CODE                            LGL_NM  \
# 0       ...  11/02/2015    UNI8303823            UNIFIRST HOLDINGS, INC
# 1       ...  12/15/2011  VS0000011560                    MARTIN T FITCH
# 2       ...  02/26/2010    WWG2097000                  W W GRAINGER INC
# 3       ...  02/08/2018  V00000926796                  Rescuegear, Inc.
# 4       ...  04/30/2014    VUL8305155     VULCAN CONSTRUCTION MATERIALS
# ...     ...         ...           ...                               ...
# 291988  ...  03/01/2013    DXI7126645                DXI INDUSTRIES INC
# 291989  ...  01/18/2019    SHI7164260      SHI-GOVERNMENT SOLUTIONS INC
# 291990  ...  09/17/2012    CLE8311044  CLEMENT'S PAINT & DECORATING INC
# 291991  ...  12/27/2013    HUG8319237          HD SUPPLY WATERWORKS LTD
# 291992  ...  01/06/2011    ERG8309949     ERGON ASPHALT & EMULSIONS INC
#
#                                AD_LN_1 AD_LN_2          CITY  ST         ZIP  \
# 0                        6000 Bolm Rd.     NaN        AUSTIN  TX  78721-3631
# 1             1304 CHARDONNAY CROSSING     NaN       Leander  TX       78641
# 2          7950 Research Blvd. Ste 101     NaN        AUSTIN  TX  78758-8425
# 3                     5909 Burnet Road     NaN        Austin  TX       78757
# 4               800 Isom Rd., Ste. 300     NaN   San Antonio  TX       78216
# ...                                ...     ...           ...  ..         ...
# 291988           1919 JACINTOPORT BLVD     NaN       HOUSTON  TX  77015-6585
# 291989  1250 S CAP OF TX HWY STE II350     NaN        AUSTIN  TX  78746-6483
# 291990          1211 W 6th St, Ste 900     NaN        AUSTIN  TX       78703
# 291991          1301 WELLS BRANCH PKWY     NaN  PFLUGERVILLE  TX       78660
# 291992    11612 FM 2244 BLDG 1 STE 250     NaN        AUSTIN  TX  78738-5516
#
#        CTRY DATA_BUILD_DATE
# 0        US      04/01/2024
# 1        US      04/01/2024
# 2        US      04/01/2024
# 3        US      04/01/2024
# 4        US      04/01/2024
# ...     ...             ...
# 291988   US      04/01/2024
# 291989   US      04/01/2024
# 291990   US      04/01/2024
# 291991   US      04/01/2024
# 291992   US      04/01/2024
#
# [291993 rows x 21 columns]>

# %%
Finance_raw.head
# Out:
# <bound method NDFrame.head of           COMMODITY                              COMMODITY_DESCRIPTION  \
# 0             20085                           Uniforms, Blended Fabric
# 1             20021  CLOTHING: ATHLETIC, CASUAL, DRESS, UNIFORM, WE...
# 2       34564115002         PROTECTOR EAR MUFF TYPE NR RATING 29/28/28
# 3             34072  Rescue Equipment, Supplies and Accessories Inc...
# 4       75035105006                             AGGREGATE TRAP ROCK 5T
# ...             ...                                                ...
# 291988        88538                                Chlorine, Liquefied
# 291989      2041362  CABLE, COMPUTER PATCH, PLENUM OR NON-PLENUM, 2...
# 291990      6305650                      PAINT, INTERIOR, ENAMEL, FLAT
# 291991  67034100006                CLAMP CI SERVICE 4 X 2 IN DBL STRAP
# 291992      7450841                                 EMULSIONS, ASPHALT
#
#                                      EXTENDED_DESCRIPTION  QUANTITY  \
# 0       R3830 - Uniform Rental & Laundry Service-Yard ...     0.000
# 1                     Champion Style C81878ST  Size Small    12.000
# 2       RC LN_____ QTY DEL_____ P/F_____ B/O_____ DEL ...    10.000
# 3                     PR354 Spec Ops Stock  NRS Throw Bag     5.000
# 4                                                     NaN   327.500
# ...                                                   ...       ...
# 291988                                Qty:22,000lbs@.2290     0.000
# 291989                                     AUXILIARY, 6FT     5.000
# 291990                                                NaN     3.000
# 291991  RC LN_____ QTY DEL_____ P/F_____ B/O_____ DEL ...     4.000
# 291992                                                NaN    63.158
#
#        UNIT_OF_MEASURE UNIT_OF_MEAS_DESC  UNIT_PRICE  ITM_TOT_AM  \
# 0                  NaN               NaN    0.000000      327.45
# 1                   PR              Pair    6.690000       80.28
# 2                   EA              Each   15.360000      153.60
# 3                   EA              Each   62.000000      310.00
# 4                 CUYD        Cubic Yard   54.540672    17862.07
# ...                ...               ...         ...         ...
# 291988             NaN               NaN    0.000000     5038.00
# 291989              EA              Each    3.000000       15.00
# 291990             CAN               Can  122.990000      368.97
# 291991              EA              Each   37.360000      149.44
# 291992              EA              Each    2.050000      129.47
#
#          MASTER_AGREEMENT                                      CONTRACT_NAME  \
# 0       MA7400NA130000062  R3830 - Uniform Laundry Serv. / Yard Trims - N...
# 1       MA8300GA080000183                                     AFD gym shorts
# 2       MA7400GC090000005                            MATERIAL NEEDED AT WBSC
# 3       MA8300GA160000040                               PR354 Spec Ops Stock
# 4       MA6200GA080000196                         Vulcan Materials/trap rock
# ...                   ...                                                ...
# 291988  MA2200GA110000036                       Liquid Chlorine in cylinders
# 291989                NaN                                             cables
# 291990                NaN  Sep. 2012 - Purchase of Paint for 411 Chicon -...
# 291991  MA2200GA120000044                            material needed at wbsc
# 291992  MA6200NA090000173                                 Ergon Asphalt/SS-1
#
#         ...  AWARD_DATE   VENDOR_CODE                            LGL_NM  \
# 0       ...  11/02/2015    UNI8303823            UNIFIRST HOLDINGS, INC
# 1       ...  12/15/2011  VS0000011560                    MARTIN T FITCH
# 2       ...  02/26/2010    WWG2097000                  W W GRAINGER INC
# 3       ...  02/08/2018  V00000926796                  Rescuegear, Inc.
# 4       ...  04/30/2014    VUL8305155     VULCAN CONSTRUCTION MATERIALS
# ...     ...         ...           ...                               ...
# 291988  ...  03/01/2013    DXI7126645                DXI INDUSTRIES INC
# 291989  ...  01/18/2019    SHI7164260      SHI-GOVERNMENT SOLUTIONS INC
# 291990  ...  09/17/2012    CLE8311044  CLEMENT'S PAINT & DECORATING INC
# 291991  ...  12/27/2013    HUG8319237          HD SUPPLY WATERWORKS LTD
# 291992  ...  01/06/2011    ERG8309949     ERGON ASPHALT & EMULSIONS INC
#
#                                AD_LN_1 AD_LN_2          CITY  ST         ZIP  \
# 0                        6000 Bolm Rd.     NaN        AUSTIN  TX  78721-3631
# 1             1304 CHARDONNAY CROSSING     NaN       Leander  TX       78641
# 2          7950 Research Blvd. Ste 101     NaN        AUSTIN  TX  78758-8425
# 3                     5909 Burnet Road     NaN        Austin  TX       78757
# 4               800 Isom Rd., Ste. 300     NaN   San Antonio  TX       78216
# ...                                ...     ...           ...  ..         ...
# 291988           1919 JACINTOPORT BLVD     NaN       HOUSTON  TX  77015-6585
# 291989  1250 S CAP OF TX HWY STE II350     NaN        AUSTIN  TX  78746-6483
# 291990          1211 W 6th St, Ste 900     NaN        AUSTIN  TX       78703
# 291991          1301 WELLS BRANCH PKWY     NaN  PFLUGERVILLE  TX       78660
# 291992    11612 FM 2244 BLDG 1 STE 250     NaN        AUSTIN  TX  78738-5516
#
#        CTRY DATA_BUILD_DATE
# 0        US      04/01/2024
# 1        US      04/01/2024
# 2        US      04/01/2024
# 3        US      04/01/2024
# 4        US      04/01/2024
# ...     ...             ...
# 291988   US      04/01/2024
# 291989   US      04/01/2024
# 291990   US      04/01/2024
# 291991   US      04/01/2024
# 291992   US      04/01/2024
#
# [291993 rows x 21 columns]>

# %%
CONNECTION_STRING_AZURE_STORAGE ="Connection key"
CONTAINER_AZURE = 'Insert your own'
blob_name ="Purchase_Order_Quantity_Price_detail_for_Commodity_Goods_procurements_20240410.csv"
output = StringIO()
Finance_raw.to_csv(output, index=False)
data = output.getvalue()
output.close()

blob_service_client= BlobServiceClient.from_connection_string(CONNECTION_STRING_AZURE_STORAGE)

blob_client = blob_service_client.get_blob_client(container=CONTAINER_AZURE, blob=blob_name)

blob_client.upload_blob(data,overwrite = True)

print(f"Uploaded {blob_name} to Azure Blob Storage in container {CONTAINER_AZURE}.")
# Out:
# Uploaded Purchase_Order_Quantity_Price_detail_for_Commodity_Goods_procurements_20240410.csv to Azure Blob Storage in container finance.
